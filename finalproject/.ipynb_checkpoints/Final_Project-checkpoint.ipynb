# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation
import pandas as pd
from ipywidgets import interact
import math
from astropy import units as u

# %%
@interact(Luminosity=(2000, 60000))
RHZinner = 0.75(math.sqrt(Luminosity/2)) *u.au
print(RHZinner)

# add another slide bar to this function with the interact decorator.    
@interact(Distance=(0, 10))
def square_number(Distance):
    print("hi")
# Out:
#   Cell In[19], line 2
#     RHZinner = 0.75(math.sqrt(Luminosity/2)) *u.au
#     ^
# SyntaxError: invalid syntax

# %%
Luminosity = 10000
Lsun = 3927.528
def find_habitability(Luminosity, Distance):
    RHZinner = 0.75(math.sqrt(Luminosity/Lsun)) *Distance(u.au)
    return RHZinner
print(find_habitability(Luminosity, Distance))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       4     RHZinner = 0.75(math.sqrt(Luminosity/Lsun)) *Distance(u.au)
#       5     return RHZinner
# ----> 6 print(find_habitability(Luminosity, Distance))
#
# Cell In[28], line 4, in find_habitability(Luminosity, Distance)
#       3 def find_habitability(Luminosity, Distance):
# ----> 4     RHZinner = 0.75(math.sqrt(Luminosity/Lsun)) *Distance(u.au)
#       5     return RHZinner
#
# TypeError: 'float' object is not callable

# %%
#psuedo code
"""
def RHZinner((Luminosity, Distance):
    use formula to determine the lowest bound of the range

def RHZupper((Luminosity, Distance):
    use formula to determine the highest bound of the range

def display_habitability(def RHZinner((Luminosity, Distance):
    if Distance is >RHZinner and <RHZupper then its hapitable:
        if Distance is <RHZinner and >RHZinner+RHZcenter/2:
            display Inner_Habitable.png
        elif Distance is <RHZcenter+RHZouter/2 and >RHZouter
            display Outer_Habitable.png
        else: 
            display Habitable_Planet.png

    else:
        if Distance<RHZinner:
            display Dry_planet
        else:
            display snowball_planet
"""

# %%
#psuedo code
"""
def display_star(Luminosity):
    if luminosity<2000 and >3500
        M_star = true
        display M Star
    elif luminosity<3500 and >5000
        K_star = true
        display K Star
    elif luminosity<5000 and >6000
        G_star = true
        display G Star
    elif luminosity<6000 and >7500
        F_star = true
        display F Star
    elif luminosity<7500 and >10000
        A_star = true
        display A Star
    elif luminosity<10000 and >30000
        B_star = true
        display B Star
    elif luminosity<30000 and >60000
        O_star = true
        display O Star

# %%
#psuedo code
"""
display background with stars
display line with rad = distance with pixels width =
insert planets and slider bar
connect planet to radius
